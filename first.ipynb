# %% [markdown]
# # Deep Learning Starter: Colab, PyTorch & Hugging Face
#
# ![Welcome Students](../assets/exercise_first/welcome.png)
#
# Welcome! In the upcoming lessons, we will be using modern AI models. Before we do that, we need to get comfortable with environment on which models work. Today, you will learn how to connect GitHub to Google Colab, use a Free GPU, load standard AI models (ResNet and CLIP), and explore massive datasets.

# %% [markdown]
# ## Task 1: Connect GitHub to Google Colab
#
# Google Colab is a free, cloud-based Python environment that is perfect for machine learning because it gives us access to powerful hardware [[1](https://colab.research.google.com/)][[2](https://research.google.com/colaboratory/faq.html#:~:text=Colab%20is%20a%20hosted%20Jupyter,%2C%20data%20science%2C%20and%20education)].
#
# 1. Create a new repository on your GitHub account (you can name it something like `vladimir-is-a-goat`).
# 2. Add a new file to this repository named `tutorial.ipynb` (the `.ipynb` extension tells GitHub it's a Jupyter Notebook).
# 3. Go to [Google Colab](https://colab.research.google.com/).
# 4. A welcome screen will pop up. Click on the GitHub tab.
# 5. Search for your GitHub username and select your repository.
# 6. Click on `tutorial.ipynb` to open it.
#
# **Tip**: Any changes you make in Colab can be saved back to GitHub by clicking **File > Save a copy in GitHub.**
#
# ![Connect Github with Google Colab](../assets/exercise_first/connect.png)

# %% [markdown]
# ## Task 2: Install Required Libraries
#
# Colab already has PyTorch and torchvision installed, but we need to add Hugging Face's libraries to easily access datasets and models.
# 1. Create a new code cell in your Colab notebook.
# 2. Type the following command: `%pip install transformers datasets huggingface_hub accelerate`
# 3. Press `Shift + Enter` to run the cell.
# 4. Wait for the installation to finish (you will see "Successfully installed..." at the bottom of the output).

# %%
# %%python --version
# Out:
# UsageError: %%python is a cell magic, but the cell body is empty.

# %%
# %pip install torch torchvision transformers datasets huggingface_hub
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# 1
# Collecting torch
#   Downloading torch-2.10.0-cp314-cp314-win_amd64.whl.metadata (31 kB)
# Collecting torchvision
#   Downloading torchvision-0.25.0-cp314-cp314-win_amd64.whl.metadata (5.4 kB)
# Collecting transformers
#   Downloading transformers-5.3.0-py3-none-any.whl.metadata (32 kB)
# Collecting datasets
#   Downloading datasets-4.6.1-py3-none-any.whl.metadata (19 kB)
# Collecting huggingface_hub
#   Downloading huggingface_hub-1.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.25.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting typing-extensions>=4.10.0 (from torch)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=0.8.5 (from torch)
#   Using cached fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# Collecting setuptools (from torch)
#   Downloading setuptools-82.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting numpy (from torchvision)
#   Using cached numpy-2.4.2-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Using cached pillow-12.1.1-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\siema\appdata\roaming\python\python314\site-packages (from transformers) (26.0)
# Collecting pyyaml>=5.1 (from transformers)
#   Downloading pyyaml-6.0.3-cp314-cp314-win_amd64.whl.metadata (2.4 kB)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2026.2.28-cp314-cp314-win_amd64.whl.metadata (41 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting typer (from transformers)
#   Downloading typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Collecting tqdm>=4.27 (from transformers)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface_hub)
#   Downloading hf_xet-1.3.2-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Collecting httpx<1,>=0.23.0 (from huggingface_hub)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting anyio (from httpx<1,>=0.23.0->huggingface_hub)
#   Downloading anyio-4.12.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting certifi (from httpx<1,>=0.23.0->huggingface_hub)
#   Downloading certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->huggingface_hub)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx<1,>=0.23.0->huggingface_hub)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting pyarrow>=21.0.0 (from datasets)
#   Downloading pyarrow-23.0.1-cp314-cp314-win_amd64.whl.metadata (3.1 kB)
# Collecting dill<0.4.1,>=0.3.0 (from datasets)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from datasets)
#   Using cached pandas-3.0.1-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting requests>=2.32.2 (from datasets)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.6.0-cp314-cp314-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.19 (from datasets)
#   Downloading multiprocess-0.70.18-py313-none-any.whl.metadata (7.2 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets)
#   Downloading aiohttp-3.13.3-cp314-cp314-win_amd64.whl.metadata (8.4 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets)
#   Using cached attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets)
#   Downloading frozenlist-1.8.0-cp314-cp314-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets)
#   Downloading multidict-6.7.1-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets)
#   Downloading propcache-0.4.1-cp314-cp314-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets)
#   Downloading yarl-1.23.0-cp314-cp314-win_amd64.whl.metadata (82 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.32.2->datasets)
#   Downloading charset_normalizer-3.4.5-cp314-cp314-win_amd64.whl.metadata (39 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.32.2->datasets)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: colorama in c:\users\siema\appdata\roaming\python\python314\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading markupsafe-3.0.3-cp314-cp314-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\siema\appdata\roaming\python\python314\site-packages (from pandas->datasets) (2.9.0.post0)
# Collecting tzdata (from pandas->datasets)
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\siema\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Collecting click>=8.2.1 (from typer->transformers)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer->transformers)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer->transformers)
#   Downloading rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer->transformers)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer->transformers)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\siema\appdata\roaming\python\python314\site-packages (from rich>=12.3.0->typer->transformers) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading torch-2.10.0-cp314-cp314-win_amd64.whl (113.8 MB)
#    ---------------------------------------- 0.0/113.8 MB ? eta -:--:--
#     --------------------------------------- 2.1/113.8 MB 15.1 MB/s eta 0:00:08
#    - -------------------------------------- 5.2/113.8 MB 15.3 MB/s eta 0:00:08
#    -- ------------------------------------- 8.4/113.8 MB 14.7 MB/s eta 0:00:08
#    ---- ----------------------------------- 11.8/113.8 MB 15.2 MB/s eta 0:00:07
#    ---- ----------------------------------- 14.2/113.8 MB 14.5 MB/s eta 0:00:07
#    ------ --------------------------------- 17.3/113.8 MB 14.6 MB/s eta 0:00:07
#    ------- -------------------------------- 20.2/113.8 MB 14.6 MB/s eta 0:00:07
#    -------- ------------------------------- 23.3/113.8 MB 14.5 MB/s eta 0:00:07
#    -------- ------------------------------- 24.9/113.8 MB 14.6 MB/s eta 0:00:07
#    --------- ------------------------------ 28.3/113.8 MB 14.2 MB/s eta 0:00:07
#    ----------- ---------------------------- 31.7/113.8 MB 14.3 MB/s eta 0:00:06
#    ----------- ---------------------------- 34.1/113.8 MB 14.0 MB/s eta 0:00:06
#    ------------ --------------------------- 37.0/113.8 MB 13.9 MB/s eta 0:00:06
#    ------------- -------------------------- 39.1/113.8 MB 13.8 MB/s eta 0:00:06
#    -------------- ------------------------- 41.7/113.8 MB 13.6 MB/s eta 0:00:06
#    --------------- ------------------------ 44.3/113.8 MB 13.5 MB/s eta 0:00:06
#    ---------------- ----------------------- 47.2/113.8 MB 13.5 MB/s eta 0:00:05
#    ----------------- ---------------------- 49.8/113.8 MB 13.5 MB/s eta 0:00:05
#    ----------------- ---------------------- 51.1/113.8 MB 13.3 MB/s eta 0:00:05
#    ------------------ --------------------- 54.0/113.8 MB 13.1 MB/s eta 0:00:05
#    -------------------- ------------------- 57.1/113.8 MB 13.2 MB/s eta 0:00:05
#    --------------------- ------------------ 60.0/113.8 MB 13.3 MB/s eta 0:00:05
#    ---------------------- ----------------- 63.4/113.8 MB 13.4 MB/s eta 0:00:04
#    ----------------------- ---------------- 67.4/113.8 MB 13.6 MB/s eta 0:00:04
#    ------------------------ --------------- 70.3/113.8 MB 13.7 MB/s eta 0:00:04
#    ------------------------- -------------- 72.4/113.8 MB 13.5 MB/s eta 0:00:04
#    -------------------------- ------------- 75.5/113.8 MB 13.6 MB/s eta 0:00:03
#    --------------------------- ------------ 79.4/113.8 MB 13.8 MB/s eta 0:00:03
#    ---------------------------- ----------- 82.3/113.8 MB 13.8 MB/s eta 0:00:03
#    ------------------------------ --------- 85.5/113.8 MB 13.8 MB/s eta 0:00:03
#    ------------------------------- -------- 88.3/113.8 MB 13.8 MB/s eta 0:00:02
#    -------------------------------- ------- 91.2/113.8 MB 13.9 MB/s eta 0:00:02
#    --------------------------------- ------ 93.8/113.8 MB 13.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 96.7/113.8 MB 13.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 99.6/113.8 MB 13.8 MB/s eta 0:00:02
#    ----------------------------------- --- 102.2/113.8 MB 13.8 MB/s eta 0:00:01
#    ----------------------------------- --- 104.6/113.8 MB 13.8 MB/s eta 0:00:01
#    ------------------------------------ -- 107.5/113.8 MB 13.8 MB/s eta 0:00:01
#    ------------------------------------- - 110.6/113.8 MB 13.8 MB/s eta 0:00:01
#    --------------------------------------  113.5/113.8 MB 13.8 MB/s eta 0:00:01
#    --------------------------------------  113.5/113.8 MB 13.8 MB/s eta 0:00:01
#    ---------------------------------------- 113.8/113.8 MB 13.4 MB/s  0:00:08
# Downloading torchvision-0.25.0-cp314-cp314-win_amd64.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ------------------------ --------------- 2.6/4.3 MB 14.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.1/4.3 MB 8.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.1/4.3 MB 8.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.1/4.3 MB 8.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.1/4.3 MB 8.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.1/4.3 MB 8.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.1/4.3 MB 8.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.1/4.3 MB 8.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.1/4.3 MB 8.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.1/4.3 MB 8.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.1/4.3 MB 8.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.1/4.3 MB 8.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.1/4.3 MB 8.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.1/4.3 MB 8.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.1/4.3 MB 8.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.1/4.3 MB 8.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.1/4.3 MB 8.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.1/4.3 MB 8.7 MB/s eta 0:00:01
#    ------------------------------------ --- 3.9/4.3 MB 942.9 kB/s eta 0:00:01
#    ---------------------------------------- 4.3/4.3 MB 1.0 MB/s  0:00:03
# Downloading transformers-5.3.0-py3-none-any.whl (10.7 MB)
#    ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/10.7 MB 4.4 MB/s eta 0:00:03
#    ------ --------------------------------- 1.8/10.7 MB 4.3 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.9/10.7 MB 4.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.5/10.7 MB 5.2 MB/s eta 0:00:02
#    --------------------- ------------------ 5.8/10.7 MB 5.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.6/10.7 MB 6.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.4/10.7 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 10.7/10.7 MB 6.6 MB/s  0:00:01
# Downloading huggingface_hub-1.5.0-py3-none-any.whl (596 kB)
#    ---------------------------------------- 0.0/596.3 kB ? eta -:--:--
#    ---------------------------------------- 596.3/596.3 kB 8.0 MB/s  0:00:00
# Downloading hf_xet-1.3.2-cp37-abi3-win_amd64.whl (3.6 MB)
#    ---------------------------------------- 0.0/3.6 MB ? eta -:--:--
#    -------------- ------------------------- 1.3/3.6 MB 6.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.6/3.6 MB 6.8 MB/s eta 0:00:01
#    ------------------------------------- -- 3.4/3.6 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.6/3.6 MB 5.5 MB/s  0:00:00
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------------------- -------------------- 1.3/2.7 MB 7.1 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.7 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 6.4 MB/s  0:00:00
# Downloading datasets-4.6.1-py3-none-any.whl (520 kB)
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
# Using cached fsspec-2026.2.0-py3-none-any.whl (202 kB)
# Downloading multiprocess-0.70.18-py313-none-any.whl (151 kB)
# Downloading aiohttp-3.13.3-cp314-cp314-win_amd64.whl (459 kB)
# Downloading multidict-6.7.1-cp314-cp314-win_amd64.whl (45 kB)
# Downloading yarl-1.23.0-cp314-cp314-win_amd64.whl (89 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading filelock-3.25.0-py3-none-any.whl (26 kB)
# Downloading frozenlist-1.8.0-cp314-cp314-win_amd64.whl (44 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    --------------- ------------------------ 0.8/2.1 MB 4.3 MB/s eta 0:00:01
#    ------------------------------ --------- 1.6/2.1 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 4.0 MB/s  0:00:00
# Using cached numpy-2.4.2-cp314-cp314-win_amd64.whl (12.4 MB)
# Using cached pillow-12.1.1-cp314-cp314-win_amd64.whl (7.2 MB)
# Downloading propcache-0.4.1-cp314-cp314-win_amd64.whl (41 kB)
# Downloading pyarrow-23.0.1-cp314-cp314-win_amd64.whl (28.2 MB)
#    ---------------------------------------- 0.0/28.2 MB ? eta -:--:--
#    - -------------------------------------- 1.0/28.2 MB 5.0 MB/s eta 0:00:06
#    -- ------------------------------------- 1.6/28.2 MB 5.2 MB/s eta 0:00:06
#    ----- ---------------------------------- 3.7/28.2 MB 5.9 MB/s eta 0:00:05
#    -------- ------------------------------- 6.3/28.2 MB 7.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 7.9/28.2 MB 7.7 MB/s eta 0:00:03
#    -------------- ------------------------- 10.2/28.2 MB 8.2 MB/s eta 0:00:03
#    ------------------- -------------------- 13.6/28.2 MB 9.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 16.8/28.2 MB 10.1 MB/s eta 0:00:02
#    --------------------------- ------------ 19.1/28.2 MB 10.3 MB/s eta 0:00:01
#    ------------------------------- -------- 22.3/28.2 MB 10.8 MB/s eta 0:00:01
#    ------------------------------------ --- 25.7/28.2 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  28.0/28.2 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 28.2/28.2 MB 11.2 MB/s  0:00:02
# Downloading pyyaml-6.0.3-cp314-cp314-win_amd64.whl (156 kB)
# Downloading regex-2026.2.28-cp314-cp314-win_amd64.whl (280 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.5-cp314-cp314-win_amd64.whl (143 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
# Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading anyio-4.12.1-py3-none-any.whl (113 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp314-cp314-win_amd64.whl (15 kB)
# Using cached pandas-3.0.1-cp314-cp314-win_amd64.whl (9.9 MB)
# Downloading setuptools-82.0.0-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 11.4 MB/s  0:00:00
# Downloading typer-0.24.1-py3-none-any.whl (56 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Downloading rich-14.3.3-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Downloading xxhash-3.6.0-cp314-cp314-win_amd64.whl (32 kB)
# Installing collected packages: mpmath, xxhash, urllib3, tzdata, typing-extensions, tqdm, sympy, shellingham, setuptools, safetensors, regex, pyyaml, pyarrow, propcache, pillow, numpy, networkx, multidict, mdurl, MarkupSafe, idna, hf-xet, h11, fsspec, frozenlist, filelock, dill, click, charset_normalizer, certifi, attrs, annotated-doc, aiohappyeyeballs, yarl, requests, pandas, multiprocess, markdown-it-py, jinja2, httpcore, anyio, aiosignal, torch, rich, httpx, aiohttp, typer, torchvision, huggingface_hub, tokenizers, datasets, transformers
#
#    ----------------------------------------  0/52 [mpmath]
#    ----------------------------------------  0/52 [mpmath]
#    ----------------------------------------  0/52 [mpmath]
#    ----------------------------------------  0/52 [mpmath]
#    ----------------------------------------  0/52 [mpmath]
#    ----------------------------------------  0/52 [mpmath]
#    ----------------------------------------  0/52 [mpmath]
#     ---------------------------------------  1/52 [xxhash]
#    - --------------------------------------  2/52 [urllib3]
#    - --------------------------------------  2/52 [urllib3]
#    -- -------------------------------------  3/52 [tzdata]
#    -- -------------------------------------  3/52 [tzdata]
#    -- -------------------------------------  3/52 [tzdata]
#    -- -------------------------------------  3/52 [tzdata]
#    -- -------------------------------------  3/52 [tzdata]
#    --- ------------------------------------  4/52 [typing-extensions]
#    --- ------------------------------------  5/52 [tqdm]
#    --- ------------------------------------  5/52 [tqdm]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ---- -----------------------------------  6/52 [sympy]
#    ----- ----------------------------------  7/52 [shellingham]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------ ---------------------------------  8/52 [setuptools]
#    ------- -------------------------------- 10/52 [regex]
#    -------- ------------------------------- 11/52 [pyyaml]
#    -------- ------------------------------- 11/52 [pyyaml]
#    --------- ------------------------------ 12/52 [pyarrow]
#    --------- ------------------------------ 12/52 [pyarrow]
#    --------- ------------------------------ 12/52 [pyarrow]
#    --------- ------------------------------ 12/52 [pyarrow]
#    --------- ------------------------------ 12/52 [pyarrow]
#    --------- ------------------------------ 12/52 [pyarrow]
#    --------- ------------------------------ 12/52 [pyarrow]
#    --------- ------------------------------ 12/52 [pyarrow]
#    --------- ------------------------------ 12/52 [pyarrow]
#    --------- ------------------------------ 12/52 [pyarrow]
#    --------- ------------------------------ 12/52 [pyarrow]
#    --------- ------------------------------ 12/52 [pyarrow]
#    --------- ------------------------------ 12/52 [pyarrow]
#    --------- ------------------------------ 12/52 [pyarrow]
#    --------- ------------------------------ 12/52 [pyarrow]
#    --------- ------------------------------ 12/52 [pyarrow]
#    ---------- ----------------------------- 14/52 [pillow]
#    ---------- ----------------------------- 14/52 [pillow]
#    ---------- ----------------------------- 14/52 [pillow]
#    ---------- ----------------------------- 14/52 [pillow]
#    ---------- ----------------------------- 14/52 [pillow]
#    ---------- ----------------------------- 14/52 [pillow]
#    ---------- ----------------------------- 14/52 [pillow]
#    ---------- ----------------------------- 14/52 [pillow]
#    ---------- ----------------------------- 14/52 [pillow]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ----------- ---------------------------- 15/52 [numpy]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------ --------------------------- 16/52 [networkx]
#    ------------- -------------------------- 17/52 [multidict]
#    --------------- ------------------------ 20/52 [idna]
#    ---------------- ----------------------- 21/52 [hf-xet]
#    ---------------- ----------------------- 22/52 [h11]
#    ----------------- ---------------------- 23/52 [fsspec]
#    ----------------- ---------------------- 23/52 [fsspec]
#    ----------------- ---------------------- 23/52 [fsspec]
#    ----------------- ---------------------- 23/52 [fsspec]
#    ------------------- -------------------- 25/52 [filelock]
#    -------------------- ------------------- 26/52 [dill]
#    -------------------- ------------------- 26/52 [dill]
#    -------------------- ------------------- 27/52 [click]
#    -------------------- ------------------- 27/52 [click]
#    --------------------- ------------------ 28/52 [charset_normalizer]
#    ----------------------- ---------------- 30/52 [attrs]
#    ----------------------- ---------------- 30/52 [attrs]
#    ------------------------- -------------- 33/52 [yarl]
#    -------------------------- ------------- 34/52 [requests]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    -------------------------- ------------- 35/52 [pandas]
#    --------------------------- ------------ 36/52 [multiprocess]
#    --------------------------- ------------ 36/52 [multiprocess]
#    --------------------------- ------------ 36/52 [multiprocess]
#    --------------------------- ------------ 36/52 [multiprocess]
#    ---------------------------- ----------- 37/52 [markdown-it-py]
#    ---------------------------- ----------- 37/52 [markdown-it-py]
#    ---------------------------- ----------- 37/52 [markdown-it-py]
#    ---------------------------- ----------- 37/52 [markdown-it-py]
#    ----------------------------- ---------- 38/52 [jinja2]
#    ----------------------------- ---------- 38/52 [jinja2]
#    ------------------------------ --------- 39/52 [httpcore]
#    ------------------------------ --------- 39/52 [httpcore]
#    ------------------------------ --------- 39/52 [httpcore]
#    ------------------------------ --------- 40/52 [anyio]
#    ------------------------------ --------- 40/52 [anyio]
#    ------------------------------ --------- 40/52 [anyio]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
# ...
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    -------------------------------- ------- 42/52 [torch]
#    --------------------------------- ------ 43/52 [rich]
#    --------------------------------- ------ 43/52 [rich]
#    --------------------------------- ------ 43/52 [rich]
#    --------------------------------- ------ 44/52 [httpx]
#    ---------------------------------- ----- 45/52 [aiohttp]
#    ---------------------------------- ----- 45/52 [aiohttp]
#    ---------------------------------- ----- 45/52 [aiohttp]
#    ----------------------------------- ---- 46/52 [typer]
#    ------------------------------------ --- 47/52 [torchvision]
#    ------------------------------------ --- 47/52 [torchvision]
#    ------------------------------------ --- 47/52 [torchvision]
#    ------------------------------------ --- 47/52 [torchvision]
#    ------------------------------------ --- 47/52 [torchvision]
#    ------------------------------------ --- 47/52 [torchvision]
#    ------------------------------------ --- 47/52 [torchvision]
#    ------------------------------------ --- 48/52 [huggingface_hub]
#    ------------------------------------ --- 48/52 [huggingface_hub]
#    ------------------------------------ --- 48/52 [huggingface_hub]
#    ------------------------------------ --- 48/52 [huggingface_hub]
#    ------------------------------------ --- 48/52 [huggingface_hub]
#    ------------------------------------- -- 49/52 [tokenizers]
#    -------------------------------------- - 50/52 [datasets]
#    -------------------------------------- - 50/52 [datasets]
#    -------------------------------------- - 50/52 [datasets]
#    -------------------------------------- - 50/52 [datasets]
#    -------------------------------------- - 50/52 [datasets]
#    -------------------------------------- - 50/52 [datasets]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------  51/52 [transformers]
#    ---------------------------------------- 52/52 [transformers]
#
# Successfully installed MarkupSafe-3.0.3 aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 annotated-doc-0.0.4 anyio-4.12.1 attrs-25.4.0 certifi-2026.2.25 charset_normalizer-3.4.5 click-8.3.1 datasets-4.6.1 dill-0.4.0 filelock-3.25.0 frozenlist-1.8.0 fsspec-2026.2.0 h11-0.16.0 hf-xet-1.3.2 httpcore-1.0.9 httpx-0.28.1 huggingface_hub-1.5.0 idna-3.11 jinja2-3.1.6 markdown-it-py-4.0.0 mdurl-0.1.2 mpmath-1.3.0 multidict-6.7.1 multiprocess-0.70.18 networkx-3.6.1 numpy-2.4.2 pandas-3.0.1 pillow-12.1.1 propcache-0.4.1 pyarrow-23.0.1 pyyaml-6.0.3 regex-2026.2.28 requests-2.32.5 rich-14.3.3 safetensors-0.7.0 setuptools-82.0.0 shellingham-1.5.4 sympy-1.14.0 tokenizers-0.22.2 torch-2.10.0 torchvision-0.25.0 tqdm-4.67.3 transformers-5.3.0 typer-0.24.1 typing-extensions-4.15.0 tzdata-2025.3 urllib3-2.6.3 xxhash-3.6.0 yarl-1.23.0
#   WARNING: The script tqdm.exe is installed in 'c:\Users\Siema\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script isympy.exe is installed in 'c:\Users\Siema\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\Siema\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\Siema\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown-it.exe is installed in 'c:\Users\Siema\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts torchfrtrace.exe and torchrun.exe are installed in 'c:\Users\Siema\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script httpx.exe is installed in 'c:\Users\Siema\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script typer.exe is installed in 'c:\Users\Siema\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts hf.exe and tiny-agents.exe are installed in 'c:\Users\Siema\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script datasets-cli.exe is installed in 'c:\Users\Siema\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script transformers.exe is installed in 'c:\Users\Siema\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# **Question:** What is `%` in Jupyter notebooks and why are we using it here?
#
# <details>
# <summary><b>Click here to see the answer</b></summary>
# <br>
#
# The **`%`** symbol denotes a **"magic command"** in Jupyter. These are special instructions that provide functionality beyond standard Python.
#
# * **In this notebook:** We use `%pip install` to ensure libraries like *PyTorch*, *torchvision*, and *transformers* are installed specifically in the current environment.
# * **Who it talks to:** The **IPython interpreter**.
#
# ---
#
# A similar symbol is **`!`**, which runs **shell commands** directly on the operating system. While `!pip install` works, **`%pip install`** is the recommended choice in Colab/Jupyter because it guarantees the package is installed in the active kernel's environment, avoiding version conflicts.
#
# * **Who it talks to:** Your computer’s **Operating System** (Terminal/CMD/Bash).
#
# #### **Other Popular Magic Commands:**
# * `%matplotlib inline`: Displays plots directly below the code cell.
# * `%time`: Measures the execution time of a single
# * `%%time`: Measures the execution time of an entire cell.
# * `%load_ext autoreload`: Automatically reloads modules before executing code.
# * `%autoreload 2`: Reloads all modules every time before executing code.
# * `%who`: Lists all variables in the current namespace.

# %% [markdown]
# ## Task 3: Activating the GPU (Graphics Processing Unit)
#
# Why do we need a GPU and what the heck is it?
#
# <details>
# <summary>Click here to see the answer</summary>
#
# A GPU (Graphics Processing Unit) is a processor originally designed for rendering graphics, but it excels at deep learning because it can perform thousands of calculations in parallel. This is essential for training deep learning models efficiently, as neural networks rely heavily on matrix multiplications that GPUs handle much faster than CPUs [[3](https://www.datacamp.com/blog/cpu-vs-gpu)].
#
# </details>
#
# Let's activate the GPU in Colab:
# 1. In your Colab notebook, click on **Runtime** in the top menu.
# 2. Select **Change runtime type**.
# 3. In the pop-up window, under **Hardware accelerator**, select **GPU**.
# 4. Click **Save**.
#
# Now, let's write our first bit of code to verify we are using the GPU with [PyTorch](https://pytorch.org/)!

# %%
import torch

# This tells PyTorch to use the GPU if it's available, otherwise fallback to CPU
device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"

print(f"You are currently using a: {device.upper()}")

# %% [markdown]
# ## Task 4: Loading a PyTorch Model (ResNet)
#
# ResNet (Residual Network) is a famous CNN (Convolutional Neural Network) model used for image classification. You can read an overview [[4](https://www.geeksforgeeks.org/deep-learning/residual-networks-resnet-deep-learning/)] or the original research paper [[5](https://arxiv.org/abs/1512.03385)].
#
# PyTorch makes it incredibly easy to load pre-trained models so let's do it!

# %%
import torchvision.models as models

# 1. Load the ResNet-18 model. "weights='DEFAULT'" loads a pre-trained version.
resnet = models.resnet18(weights='DEFAULT')
print(type(resnet))

# 2. Move the model to our device (GPU)
resnet = resnet.to(device)
resnet.eval()  # Set the model to evaluation mode (important for inference)

print("ResNet successfully loaded and moved to:", device)

# %% [markdown]
# ## Task 5: Loading the ImageNet-1k Dataset
#
# [ImageNet-1k](https://huggingface.co/datasets/ILSVRC/imagenet-1k) is one of the most famous datasets in AI, containing over 1.2 million images across 1,000 categories. It's massive (over 100 GB!).
#
# Instead of downloading the whole thing—which would crash our Colab—we will use the Hugging Face `datasets` library to "stream" it. Streaming means we only download the images we are looking at right now, like watching a YouTube video.
#
# But first, before we load the dataset we need to connect to our Hugging Face account. Hugging Face is a platform that hosts datasets and models for AI research and sometimes requires authentication to access certain resources as it is in the case of ImageNet-1k.
#
# ![Access problem](../assets/exercise_first/denied.png)
#
# To create an account go to [Hugging Face](https://huggingface.co/) and sign up. Once you have an account:
#
# 1. Visit the [ImageNet-1k dataset page](https://huggingface.co/datasets/ILSVRC/imagenet-1k) and click **"Agree and access repository"** to request access. Without this step, you will receive a 403 error even with a valid token.
# 2. Create a [User Access Token](https://hf.co/docs/hub/security-tokens#user-access-tokens) and log in to your account.
#
# Paste your User Access Token into [notebook_login](https://huggingface.co/docs/huggingface_hub/main/en/package_reference/authentication#huggingface_hub.notebook_login) when prompted to log in.

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
from datasets import load_dataset

# We use streaming=True to avoid downloading 100+ GB of data!
print("Connecting to ImageNet-1k...")
dataset = load_dataset("imagenet-1k", split="train", streaming=True, trust_remote_code=True)
print(type(dataset))

# Look at the very first image in the dataset
iterator = iter(dataset)
first_sample = next(iterator)

print("\nDataset Labels:", first_sample['label'])
first_sample['image']

# %% [markdown]
# ## Task 6: Loading CLIP from Hugging Face
#
# Use the [Hugging Face webpage](https://huggingface.co/openai/clip-vit-base-patch32) of the `openai/clip-vit-base-patch32` to learn how to load the CLIP model and its corresponding processor.

# %%
from transformers import CLIPProcessor, CLIPModel
from PIL import Image
import requests

# 1. Load the model and the processor (which prepares our images/text for the model)
model_id = "openai/clip-vit-base-patch32"
### STUDENT CODE HERE ###
clip_model.to(device)

# 2. Get a sample image from the internet
url = "http://images.cocodataset.org/val2017/000000039769.jpg"
image = Image.open(requests.get(url, stream=True).raw)

# 3. Give the model some text options to guess what is in the image
text_options = ["a photo of a cat", "a photo of a dog", "a photo of a car"]

# 4. Process the inputs and run the model!
### STUDENT CODE HERE ###
outputs = clip_model(**inputs)

# 5. Look at the results
logits_per_image = outputs.logits_per_image
probs = logits_per_image.softmax(dim=1) 

print("Probability it is a cat:", probs[0][0].item())
print("Probability it is a dog:", probs[0][1].item())
print("Probability it is a car:", probs[0][2].item())

# %% [markdown]
# ## Task 7: Run ResNet on the Image
#
# Let's pass our ImageNet picture (loaded in Task 6) into the ResNet model and see what it predicts.
#
# > **Note:** This task depends on the `image` variable defined in Task 6. Make sure you have run Task 6 first.
#
# After running, you will see a predicted class ID (e.g. `281`). These integer IDs correspond to one of ImageNet's 1,000 categories — for example, ID 281 is "tabby cat". You can look up any class ID in the [ImageNet class index](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
from torchvision import transforms

# ResNet requires images to be resized and normalized in a very specific way
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Process the image and move it to the GPU
### STUDENT CODE HERE ###
print(input_tensor.shape)  # Should be [1, 3, 224, 224]

# Run the model
with torch.inference_mode():
    ### STUDENT CODE HERE ###
print(output.shape) # Should be [1, 1000]

# Get the highest predicted score
predicted_class = output.argmax(dim=1).item()
print(f"ResNet predicts this is class ID: {predicted_class}")

# %% [markdown]
# ![Bravo my students!](../assets/exercise_first/sucess.png)
#
# Yey! You now have a working Colab notebook connected to GitHub, utilizing a GPU, running PyTorch models, streaming massive datasets, and executing multi-modal Hugging Face models.

# %% [markdown]
# ## Task 8: Find and Use an LLM (Large Language Model)
#
# Hugging Face has thousands of text models. Let's use `Qwen/Qwen2.5-1.5B-Instruct`, a modern, small text generation model that will easily fit on our Colab GPU alongside the vision models we already loaded.

# %%
### STUDENT CODE HERE ###

# %% [markdown]
# ## Task 9: Use the BLIP-2 Model
#
# [BLIP-2](https://huggingface.co/Salesforce/blip2-opt-2.7b) is an advanced multi-modal model by Salesforce. Instead of just picking from categories like ResNet or CLIP, BLIP-2 can actually look at an image and generate a conversational text answer to a question you ask it (Visual Question Answering).

# %%
### STUDENT CODE HERE ###

# %% [markdown]
# ## Additional Task 10: GPU Memory Management and running a Massive LLM
#
# ![GPU Memory](../assets/exercise_first/problem.png)
#
# If we want to load a state-of-the-art Large Language Model (LLM), we need to clear out the models we just used to free up our GPU's memory. Otherwise, our notebook will crash.
#
# - Show 3 different ways to clear GPU memory in PyTorch.
# - Load a massive LLM like `mistralai/Mistral-7B-Instruct-v0.1` and run it on a simple prompt.

# %%
### STUDENT CODE HERE for clearing the GPU memory ###

# %%
### STUDENT CODE HERE for using mistral model ###

# %% [markdown]
# ## Summary
#
# In this lesson, we connected GitHub to Google Colab, installed necessary libraries, activated the GPU, loaded a pre-trained ResNet model, streamed the ImageNet-1k dataset, and explored how to use Hugging Face models like CLIP, Qwen, and BLIP-2. You are now ready to dive deeper into researching and fine-tuning your own AI models!
#
# The points table of the lesson is as follows:
# - Tasks 1-3: 1 point
# - Tasks 4-5: 1 point
# - Tasks 6-7: 1 point
# - Tasks 8-9: 1 point
# - Task 10: Additional 2 points (optional)
#
# Additional reading for those who want to learn more:
# - [Colab](https://colab.research.google.com/)
# - [Using Hugging Face Models in Google Colab](https://dev.to/ajmal_hasan/using-hugging-face-models-in-google-colab-a-beginners-35ll)
#
# ![Goodbye](../assets/exercise_first/goodbay.png)
